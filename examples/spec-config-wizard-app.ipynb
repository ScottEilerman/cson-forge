# %% [markdown]
# # C-STAR Forge — SpecConfig builder
#
# Assemble a reproducible `spec_config.yml`: pick a **Model** and **Domain**, adjust
# the grid, boundaries, partitioning, and run window, review the resolved config, then
# **Download** it. Take that file to your machine of choice to run the processing step.

# %%
from cstar_forge.spec_config_wizard import SpecConfigWizard

SpecConfigWizard().display()
