# %% [markdown]
# # Making a new domain: `CStarSpecBuilder`
#
# This notebook demonstrates how to create a new domain and run a ROMS simulation using C-STAR Forge.

# %% [markdown]
# ## Setup
#
# First, import the necessary modules and define the domain configuration parameters.

# %%
# %load_ext autoreload
# %autoreload 2

import cstar_forge
import cstar.execution.handler as handler
import time
from datetime import datetime
from IPython.display import Markdown, display

# %% [markdown]
# ## Environment and Machine Information
#
# Record the execution environment and machine details for reproducibility.

# %%
env = cstar_forge.config.get_environment_info()

# Display summary
summary = f"""
### Machine Information
- **Hostname**: `{env.hostname}`
- **System Tag**: `{env.system_tag}`
- **OS**: `{env.os_info}`

### Environment Summary
- **Python Version**: `{env.python_version}`
- **Python Executable**: `{env.python_executable}`
- **Conda/Micromamba Environment**: `{env.env_info}`
- **Kernel**: `{env.kernel_spec}`
"""

display(Markdown(summary))
print(f"Execution timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ### Machine Information
# - **Hostname**: `Mac-36`
# - **System Tag**: `MacOS`
# - **OS**: `Darwin 25.5.0 (arm64)`
#
# ### Environment Summary
# - **Python Version**: `3.12.13`
# - **Python Executable**: `/Users/eilerman/miniconda3/envs/cstar-forge-v0/bin/python`
# - **Conda/Micromamba Environment**: `cstar-forge-v0 (/Users/eilerman/miniconda3/envs/cstar-forge-v0)`
# - **Kernel**: `cstar-forge-v0 (ipykernel 7.2.0)`
# Execution timestamp: 2026-06-15 14:28:21

# %%
grid_name = "test-tiny"
model_name = "cson_roms-marbl_v0.1"
start_time = datetime(2012, 1, 1)
end_time = datetime(2012, 1, 2)

grid_kwargs = dict[str, float](
    nx=6,
    ny=2,
    size_x=500,
    size_y=1000,
    center_lon=0,
    center_lat=55,
    rot=10,
    N=3,  # number of vertical levels
    theta_s=5.0,  # surface control parameter
    theta_b=2.0,  # bottom control parameter
    hc=250.0,  # critical depth
)

boundaries={
        "south": False,
        "east": True,
        "north": True,
        "west": False, 
    }

partitioning = {
    "n_procs_x": 1, # number of partitions in xi (x) 
    "n_procs_y": 1, # number of partitions in eta (y) 
}

# %% [markdown]
# ## Generate CDR Forcing for this grid using ROMS-tools

# %%
from roms_tools import TracerPerturbation, CDRForcing, Grid

tp = TracerPerturbation(
    name="my_cdr",
    lat=grid_kwargs["center_lat"]+4,  # degree N
    lon=grid_kwargs["center_lon"]+1,  # degree E
    hsc=10,
    vsc=10,
    depth=1,  # m
    tracer_fluxes={"ALK": 2 * 10**6},  # meq/s
)

cdr = CDRForcing(
    grid=Grid(**grid_kwargs), # for plotting, could omit
    start_time=start_time,
    end_time=end_time,
    releases=[tp],
)

cdr.plot_locations()
cdr.plot_distribution("my_cdr")
cdr.plot_tracer_flux("ALK")

# we should decide how we want to pass the cdr information:
# dict/kwargs? yaml file? object?
cdr_as_dict = cdr.model_dump()["CDRForcing"]

# cdr_as_dict

# %% [markdown]
# ## Initialize CstarSpecBuilder
#
# Create a `CstarSpecBuilder` instance with the domain configuration. This initializes the PRECONFIG stage, creating the grid object and blueprint structure.

# %%
ocn = cstar_forge.CstarSpecBuilder(
    description="Test tiny",
    model_name=model_name,
    grid_name=grid_name,
    grid_kwargs=grid_kwargs,
    open_boundaries=boundaries,    
    start_time=start_time,
    end_time=end_time,
    partitioning=partitioning,
    cdr_forcing = cdr_as_dict,
    #catalog_root="local"
)
# Out:
# Note: No catalog_root specified. Using internal cstar-forge catalog for ModelSpec and MachineSpec (default/example values).
#       Blueprints will be written to: /Users/eilerman/cstar-forge-data/catalog
#       To use a custom catalog, set catalog_root=<path> or catalog_root='default' when creating CstarSpecBuilder.
# CstarSpecBuilder: planned NetCDF outputs
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_grid.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_initial_conditions.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-physics.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc-co2.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-physics.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-bgc.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_tidal.nc
#   - /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_river.nc
#
# CstarSpecBuilder: output locations
#   NetCDF files: /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs
#   YAML files: /Users/eilerman/cstar-forge-data/catalog/blueprints/MacOS/cson_roms-marbl_v0.1_test-tiny_1procs
#   Compile-time code: /Users/eilerman/cstar-forge-data/catalog/blueprints/MacOS/cson_roms-marbl_v0.1_test-tiny_1procs/Build/compile-time
#   Run-time code: /Users/eilerman/cstar-forge-data/catalog/blueprints/MacOS/cson_roms-marbl_v0.1_test-tiny_1procs/Build/run-time
#   Simulation output (scratch): /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102

# %% [markdown]
# ### Visualize the grid

# %%
ocn.grid.plot()

# %% [markdown]
# ## Prepare Source Data
#
# Ensure that all required source datasets (GLORYS, UNIFIED, SRTM15, etc.) are staged locally. This downloads and prepares the data needed for input generation.

# %%
# ensure that source data is staged locally
ocn.ensure_source_data()
# Out:
# ✔️  Using existing GLORYS_REGIONAL file for 2011-12-31: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_test-tiny_20111231.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_test-tiny_20120101.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_test-tiny_20120102.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-03: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_test-tiny_20120103.nc
# ✔️  Using existing MBL_CO2 dataset: /Users/eilerman/cstar-forge-data/source-data/MBL_CO2/co2_GHGreference.1785677502_surface.txt
# ✔️  TPXO dataset verified at: /Users/eilerman/cstar-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /Users/eilerman/cstar-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc

# %% [markdown]
# ## Generate Input Files
#
# Generate all model input files (grid, initial conditions, forcing) from the source data. This completes the POSTCONFIG stage and updates the blueprint with actual file paths.
#
# The system will look for an existing blueprint and, if a match is found, it will use that data unless the user sets `clobber=True` to force re-generating the data.

# %%
# prepare model input
ocn.generate_inputs(clobber=True) # setting clobber=True will overwrite existing files
# Out:
# ⚠️  Clobber=True: removing 13 existing .nc files in /Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs...
#
# ▶️  [1/10] Writing ROMS grid...
#
# ▶️  [2/10] Generating initial conditions...
# 2026-06-15 20:28:23,905 [WARNING] - utils.py:109 - Optional variables missing (but not critical): ['Lig', 'DIC_ALT_CO2', 'Alk_ALT_CO2']
# [########################################] | 100% Completed | 1.66 sms
#
# ▶️  [3/10] Generating surface forcing...
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# [########################################] | 100% Completed | 321.78 ms
# [########################################] | 100% Completed | 1.16 sms
#
# ▶️  [4/10] Generating surface forcing...
# [########################################] | 100% Completed | 108.76 ms
#
# ▶️  [5/10] Generating surface forcing...
#
# ▶️  [6/10] Generating boundary forcing...
# [########################################] | 100% Completed | 105.39 ms
# [########################################] | 100% Completed | 318.30 ms
# 2026-06-15 20:28:46,397 [WARNING] - utils.py:109 - Optional variables missing (but not critical): ['Lig', 'DIC_ALT_CO2', 'Alk_ALT_CO2']
# ▶️  [7/10] Generating boundary forcing...
# [########################################] | 100% Completed | 3.78 sms
#
# ▶️  [8/10] Generating tidal forcing...
# [########################################] | 100% Completed | 14.53 s
#
# ▶️  [9/10] Generating river forcing...
# 2026-06-15 20:29:26,236 [WARNING] - cdr_forcing.py:1063 - Grid not provided: cannot verify whether the specified lat/lon/depth location is within the domain or on land. Please check manually or provide a grid when instantiating the class.
# ▶️  [10/10] Generating CDR forcing...
#
# ✅ All input files generated.
# RomsMarblBlueprint(name='cson_roms-marbl_v0.1_test-tiny_1procs', description='Test tiny', application='roms_marbl', state=<BlueprintState.NotSet: 'notset'>, schema_version='', valid_start_date=datetime.datetime(2012, 1, 1, 0, 0), valid_end_date=datetime.datetime(2012, 1, 2, 0, 0), code={'roms': {'documentation': '', 'locked': False, 'location': 'https://github.com/CWorthy-ocean/ucla-roms.git', 'commit': 'bc7ee7d5ffd8d18741e02daa49c6d2845a4589ca', 'branch': '', 'filter': None}, 'run_time': {'documentation': '', 'locked': False, 'location': 'placeholder://run_time', 'commit': '', 'branch': 'main', 'filter': None}, 'compile_time': {'documentation': '', 'locked': False, 'location': 'placeholder://compile_time', 'commit': '', 'branch': 'main', 'filter': None}, 'marbl': {'documentation': '', 'locked': False, 'location': 'https://github.com/marbl-ecosys/MARBL.git', 'commit': 'marbl0.45.0', 'branch': '', 'filter': None}}, initial_conditions={'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_initial_conditions.nc'), 'partitioned': False}]}, grid={'documentation': '', 'locked': False, 'data': [{'location': '/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_grid.nc', 'partitioned': False}]}, forcing={'boundary': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-physics_201112.nc'), 'partitioned': False}, {'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-physics_201201.nc'), 'partitioned': False}, {'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-bgc_clim.nc'), 'partitioned': False}]}, 'surface': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-physics_201112.nc'), 'partitioned': False}, {'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-physics_201201.nc'), 'partitioned': False}, {'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc_clim.nc'), 'partitioned': False}, {'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc-co2_2011.nc'), 'partitioned': False}, {'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc-co2_2012.nc'), 'partitioned': False}]}, 'tidal': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_tidal.nc'), 'partitioned': False}]}, 'river': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_river.nc'), 'partitioned': False}]}, 'corrections': None}, partitioning={'documentation': '', 'locked': False, 'hash': None, 'n_procs_x': 1, 'n_procs_y': 1}, model_params=None, runtime_params=None, cdr_forcing={'documentation': '', 'locked': False, 'data': [{'location': '/Users/eilerman/cstar-forge-data/input-data/cson_roms-marbl_v0_1_test-tiny_1procs/cson_roms-marbl_v0_1_test-tiny_1procs_cdr.nc', 'partitioned': False}]}, nesting_info=None)

# %% [markdown]
# ## Access Generated Input Datasets
#
# Input datasets are available on the `datasets` attribute of the `CstarSpecBuilder` after `generate_inputs()` has completed. The `datasets` dictionary only contains keys for fields that exist in the blueprint and have been successfully generated.
#
# **Note:** Datasets are only available after `generate_inputs()` has run and populated the blueprint with actual file paths. If a key doesn't exist, it means that field wasn't generated or isn't in the blueprint.

# %%
for key in ocn.datasets.keys():
    print("-"*100)
    print(key)
    print(ocn.datasets[key])
# Out:
# ----------------------------------------------------------------------------------------------------
# grid
# <xarray.Dataset> Size: 3kB
# Dimensions:       (eta_rho: 4, xi_rho: 8, xi_u: 7, eta_v: 3, eta_coarse: 3,
#                    xi_coarse: 5, s_rho: 3, s_w: 4)
# Coordinates:
#     lat_rho       (eta_rho, xi_rho) float64 256B ...
#     lon_rho       (eta_rho, xi_rho) float64 256B ...
#     lat_u         (eta_rho, xi_u) float64 224B ...
#     lon_u         (eta_rho, xi_u) float64 224B ...
#     lat_v         (eta_v, xi_rho) float64 192B ...
#     lon_v         (eta_v, xi_rho) float64 192B ...
#     lat_coarse    (eta_coarse, xi_coarse) float64 120B ...
#     lon_coarse    (eta_coarse, xi_coarse) float64 120B ...
# Dimensions without coordinates: eta_rho, xi_rho, xi_u, eta_v, eta_coarse,
#                                 xi_coarse, s_rho, s_w
# Data variables: (12/15)
#     angle         (eta_rho, xi_rho) float64 256B ...
#     f             (eta_rho, xi_rho) float64 256B ...
#     pm            (eta_rho, xi_rho) float64 256B ...
#     pn            (eta_rho, xi_rho) float64 256B ...
#     spherical     |S1 1B ...
#     mask_rho      (eta_rho, xi_rho) int32 128B ...
#     ...            ...
#     mask_coarse   (eta_coarse, xi_coarse) int32 60B ...
#     h             (eta_rho, xi_rho) float64 256B ...
#     sigma_r       (s_rho) float32 12B ...
#     Cs_r          (s_rho) float32 12B ...
#     sigma_w       (s_w) float32 16B ...
#     Cs_w          (s_w) float32 16B ...
# Attributes: (12/14)
#     title:                   ROMS grid created by ROMS-Tools
#     roms_tools_version:      4.0.0a1
#     size_x:                  500
#     size_y:                  1000
#     center_lon:              0
#     center_lat:              55
#     ...                      ...
#     close_narrow_channels:   False
#     topography_source_name:  ETOPO5
#     hmin:                    5.0
#     theta_s:                 5.0
#     theta_b:                 2.0
#     hc:                      250.0
# ----------------------------------------------------------------------------------------------------
# initial_conditions
# <xarray.Dataset> Size: 15kB
# Dimensions:      (ocean_time: 1, s_rho: 3, eta_rho: 4, xi_rho: 8, xi_u: 7,
#                   eta_v: 3, s_w: 4)
# Coordinates:
#     abs_time     (ocean_time) datetime64[ns] 8B ...
#   * ocean_time   (ocean_time) float64 8B 3.787e+08
# Dimensions without coordinates: s_rho, eta_rho, xi_rho, xi_u, eta_v, s_w
# Data variables: (12/42)
#     temp         (ocean_time, s_rho, eta_rho, xi_rho) float32 384B ...
#     salt         (ocean_time, s_rho, eta_rho, xi_rho) float32 384B ...
#     u            (ocean_time, s_rho, eta_rho, xi_u) float32 336B ...
#     v            (ocean_time, s_rho, eta_v, xi_rho) float32 288B ...
#     zeta         (ocean_time, eta_rho, xi_rho) float32 128B ...
#     ubar         (ocean_time, eta_rho, xi_u) float32 112B ...
#     ...           ...
#     Lig          (ocean_time, s_rho, eta_rho, xi_rho) float32 384B ...
#     DIC_ALT_CO2  (ocean_time, s_rho, eta_rho, xi_rho) float32 384B ...
#     ALK_ALT_CO2  (ocean_time, s_rho, eta_rho, xi_rho) float32 384B ...
#     w            (ocean_time, s_w, eta_rho, xi_rho) float32 512B ...
#     Cs_r         (s_rho) float32 12B ...
#     Cs_w         (s_w) float32 16B ...
# Attributes:
#     title:                                ROMS initial conditions file create...
#     roms_tools_version:                   4.0.0a1
#     ini_time:                             2012-01-01 00:00:00
#     model_reference_date:                 2000-01-01 00:00:00
#     adjust_depth_for_sea_surface_height:  False
#     source:                               GLORYS
#     bgc_source:                           UNIFIED
#     theta_s:                              5.0
#     theta_b:                              2.0
#     hc:                                   250.0
# ----------------------------------------------------------------------------------------------------
# forcing.surface
# [<xarray.Dataset> Size: 920B
# Dimensions:   (time: 1, eta_rho: 4, xi_rho: 8)
# Coordinates:
#     abs_time  (time) datetime64[ns] 8B ...
#   * time      (time) float64 8B 4.383e+03
#     rad_time  (time) float64 8B ...
# Dimensions without coordinates: eta_rho, xi_rho
# Data variables:
#     uwnd      (time, eta_rho, xi_rho) float32 128B ...
#     vwnd      (time, eta_rho, xi_rho) float32 128B ...
#     swrad     (time, eta_rho, xi_rho) float32 128B ...
#     lwrad     (time, eta_rho, xi_rho) float32 128B ...
#     Tair      (time, eta_rho, xi_rho) float32 128B ...
#     rain      (time, eta_rho, xi_rho) float32 128B ...
#     qair      (time, eta_rho, xi_rho) float32 128B ...
# Attributes:
#     title:                 ROMS surface forcing file created by ROMS-Tools
#     roms_tools_version:    4.0.0a1
#     start_time:            2012-01-01 00:00:00
#     end_time:              2012-01-02 00:00:00
#     source:                ERA5
#     correct_radiation:     True
#     wind_dropoff:          False
#     use_coarse_grid:       False
#     model_reference_date:  2000-01-01 00:00:00
#     type:                  physics, <xarray.Dataset> Size: 25kB
# Dimensions:   (time: 27, eta_rho: 4, xi_rho: 8)
# Coordinates:
#     abs_time  (time) datetime64[ns] 216B ...
#   * time      (time) float64 216B 4.383e+03 4.383e+03 ... 4.384e+03 4.384e+03
#     rad_time  (time) float64 216B ...
# Dimensions without coordinates: eta_rho, xi_rho
# Data variables:
#     uwnd      (time, eta_rho, xi_rho) float32 3kB ...
#     vwnd      (time, eta_rho, xi_rho) float32 3kB ...
#     swrad     (time, eta_rho, xi_rho) float32 3kB ...
#     lwrad     (time, eta_rho, xi_rho) float32 3kB ...
#     Tair      (time, eta_rho, xi_rho) float32 3kB ...
#     rain      (time, eta_rho, xi_rho) float32 3kB ...
#     qair      (time, eta_rho, xi_rho) float32 3kB ...
# Attributes:
#     title:                 ROMS surface forcing file created by ROMS-Tools
#     roms_tools_version:    4.0.0a1
#     start_time:            2012-01-01 00:00:00
#     end_time:              2012-01-02 00:00:00
#     source:                ERA5
#     correct_radiation:     True
#     wind_dropoff:          False
#     use_coarse_grid:       False
#     model_reference_date:  2000-01-01 00:00:00
#     type:                  physics, <xarray.Dataset> Size: 7kB
# Dimensions:    (time: 12, eta_rho: 4, xi_rho: 8)
# Coordinates:
#     month      (time) int32 48B ...
#     abs_time   (time) datetime64[ns] 96B ...
#     iron_time  (time) float64 96B ...
#     dust_time  (time) float64 96B ...
#     nox_time   (time) float64 96B ...
#     nhy_time   (time) float64 96B ...
# Dimensions without coordinates: time, eta_rho, xi_rho
# Data variables:
#     dust       (time, eta_rho, xi_rho) float32 2kB ...
#     iron       (time, eta_rho, xi_rho) float32 2kB ...
#     nox        (time, eta_rho, xi_rho) float32 2kB ...
#     nhy        (time, eta_rho, xi_rho) float32 2kB ...
# Attributes:
#     title:                 ROMS surface forcing file created by ROMS-Tools
#     roms_tools_version:    4.0.0a1
#     start_time:            2012-01-01 00:00:00
#     end_time:              2012-01-02 00:00:00
#     source:                UNIFIED
#     correct_radiation:     False
#     wind_dropoff:          False
#     use_coarse_grid:       False
#     model_reference_date:  2000-01-01 00:00:00
#     type:                  bgc
#     climatology:           True, <xarray.Dataset> Size: 272B
# Dimensions:       (time: 1, eta_rho: 4, xi_rho: 8)
# Coordinates:
#     abs_time      (time) datetime64[ns] 8B ...
#     xco2_time     (time) float64 8B ...
# Dimensions without coordinates: time, eta_rho, xi_rho
# Data variables:
#     xco2_air      (time, eta_rho, xi_rho) float32 128B ...
#     xco2_air_alt  (time, eta_rho, xi_rho) float32 128B ...
# Attributes:
#     title:                 ROMS surface forcing file created by ROMS-Tools
#     roms_tools_version:    4.0.0a1
#     start_time:            2012-01-01 00:00:00
#     end_time:              2012-01-02 00:00:00
#     source:                MBL_co2
#     correct_radiation:     False
#     wind_dropoff:          False
#     use_coarse_grid:       False
#     model_reference_date:  2000-01-01 00:00:00
#     type:                  bgc, <xarray.Dataset> Size: 544B
# Dimensions:       (time: 2, eta_rho: 4, xi_rho: 8)
# Coordinates:
#     abs_time      (time) datetime64[ns] 16B ...
#     xco2_time     (time) float64 16B ...
# Dimensions without coordinates: time, eta_rho, xi_rho
# Data variables:
#     xco2_air      (time, eta_rho, xi_rho) float32 256B ...
#     xco2_air_alt  (time, eta_rho, xi_rho) float32 256B ...
# Attributes:
#     title:                 ROMS surface forcing file created by ROMS-Tools
#     roms_tools_version:    4.0.0a1
#     start_time:            2012-01-01 00:00:00
#     end_time:              2012-01-02 00:00:00
#     source:                MBL_co2
#     correct_radiation:     False
#     wind_dropoff:          False
#     use_coarse_grid:       False
#     model_reference_date:  2000-01-01 00:00:00
#     type:                  bgc]
# ----------------------------------------------------------------------------------------------------
# forcing.boundary
# [<xarray.Dataset> Size: 704B
# Dimensions:     (bry_time: 1, s_rho: 3, xi_u: 7, xi_rho: 8, eta_rho: 4, eta_v: 3)
# Coordinates:
#     abs_time    (bry_time) datetime64[ns] 8B ...
#   * bry_time    (bry_time) float64 8B 4.382e+03
# Dimensions without coordinates: s_rho, xi_u, xi_rho, eta_rho, eta_v
# Data variables: (12/14)
#     u_north     (bry_time, s_rho, xi_u) float32 84B ...
#     v_north     (bry_time, s_rho, xi_rho) float32 96B ...
#     temp_north  (bry_time, s_rho, xi_rho) float32 96B ...
#     salt_north  (bry_time, s_rho, xi_rho) float32 96B ...
#     zeta_north  (bry_time, xi_rho) float32 32B ...
#     ubar_north  (bry_time, xi_u) float32 28B ...
#     ...          ...
#     v_east      (bry_time, s_rho, eta_v) float32 36B ...
#     temp_east   (bry_time, s_rho, eta_rho) float32 48B ...
#     salt_east   (bry_time, s_rho, eta_rho) float32 48B ...
#     zeta_east   (bry_time, eta_rho) float32 16B ...
#     ubar_east   (bry_time, eta_rho) float32 16B ...
#     vbar_east   (bry_time, eta_v) float32 12B ...
# Attributes:
#     title:                                ROMS boundary forcing file created ...
#     roms_tools_version:                   4.0.0a1
#     start_time:                           2012-01-01 00:00:00
#     end_time:                             2012-01-02 00:00:00
#     source:                               GLORYS
#     model_reference_date:                 2000-01-01 00:00:00
#     apply_2d_horizontal_fill:             False
#     adjust_depth_for_sea_surface_height:  False
#     theta_s:                              5.0
#     theta_b:                              2.0
#     hc:                                   250.0, <xarray.Dataset> Size: 2kB
# Dimensions:     (bry_time: 3, s_rho: 3, xi_u: 7, xi_rho: 8, eta_rho: 4, eta_v: 3)
# Coordinates:
#     abs_time    (bry_time) datetime64[ns] 24B ...
#   * bry_time    (bry_time) float64 24B 4.383e+03 4.384e+03 4.385e+03
# Dimensions without coordinates: s_rho, xi_u, xi_rho, eta_rho, eta_v
# Data variables: (12/14)
#     u_north     (bry_time, s_rho, xi_u) float32 252B ...
#     v_north     (bry_time, s_rho, xi_rho) float32 288B ...
#     temp_north  (bry_time, s_rho, xi_rho) float32 288B ...
#     salt_north  (bry_time, s_rho, xi_rho) float32 288B ...
#     zeta_north  (bry_time, xi_rho) float32 96B ...
#     ubar_north  (bry_time, xi_u) float32 84B ...
#     ...          ...
#     v_east      (bry_time, s_rho, eta_v) float32 108B ...
#     temp_east   (bry_time, s_rho, eta_rho) float32 144B ...
#     salt_east   (bry_time, s_rho, eta_rho) float32 144B ...
#     zeta_east   (bry_time, eta_rho) float32 48B ...
#     ubar_east   (bry_time, eta_rho) float32 48B ...
#     vbar_east   (bry_time, eta_v) float32 36B ...
# Attributes:
#     title:                                ROMS boundary forcing file created ...
#     roms_tools_version:                   4.0.0a1
#     start_time:                           2012-01-01 00:00:00
#     end_time:                             2012-01-02 00:00:00
#     source:                               GLORYS
#     model_reference_date:                 2000-01-01 00:00:00
#     apply_2d_horizontal_fill:             False
#     adjust_depth_for_sea_surface_height:  False
#     theta_s:                              5.0
#     theta_b:                              2.0
#     hc:                                   250.0, <xarray.Dataset> Size: 56kB
# Dimensions:            (bry_time: 12, s_rho: 3, xi_rho: 8, eta_rho: 4)
# Coordinates:
#     month              (bry_time) int32 48B ...
#     abs_time           (bry_time) datetime64[ns] 96B ...
#   * bry_time           (bry_time) float64 96B 15.5 45.0 74.5 ... 319.0 349.5
# Dimensions without coordinates: s_rho, xi_rho, eta_rho
# Data variables: (12/64)
#     PO4_north          (bry_time, s_rho, xi_rho) float32 1kB ...
#     NO3_north          (bry_time, s_rho, xi_rho) float32 1kB ...
#     SiO3_north         (bry_time, s_rho, xi_rho) float32 1kB ...
#     Fe_north           (bry_time, s_rho, xi_rho) float32 1kB ...
#     O2_north           (bry_time, s_rho, xi_rho) float32 1kB ...
#     DIC_north          (bry_time, s_rho, xi_rho) float32 1kB ...
#     ...                 ...
#     diazFe_east        (bry_time, s_rho, eta_rho) float32 576B ...
#     spCaCO3_east       (bry_time, s_rho, eta_rho) float32 576B ...
#     zooC_east          (bry_time, s_rho, eta_rho) float32 576B ...
#     Lig_east           (bry_time, s_rho, eta_rho) float32 576B ...
#     DIC_ALT_CO2_east   (bry_time, s_rho, eta_rho) float32 576B ...
#     ALK_ALT_CO2_east   (bry_time, s_rho, eta_rho) float32 576B ...
# Attributes:
#     title:                                ROMS boundary forcing file created ...
#     roms_tools_version:                   4.0.0a1
#     start_time:                           2012-01-01 00:00:00
#     end_time:                             2012-01-02 00:00:00
#     source:                               UNIFIED
#     model_reference_date:                 2000-01-01 00:00:00
#     apply_2d_horizontal_fill:             False
#     adjust_depth_for_sea_surface_height:  False
#     theta_s:                              5.0
#     theta_b:                              2.0
#     hc:                                   250.0
#     climatology:                          True]
# ----------------------------------------------------------------------------------------------------
# forcing.tidal
# <xarray.Dataset> Size: 14kB
# Dimensions:  (ntides: 15, eta_rho: 4, xi_rho: 8, xi_u: 7, eta_v: 3)
# Coordinates:
#   * ntides   (ntides) |S3 45B b'm2' b's2' b'n2' b'k2' ... b'ms4' b'2n2' b's1'
#     omega    (ntides) float64 120B ...
# Dimensions without coordinates: eta_rho, xi_rho, xi_u, eta_v
# Data variables:
#     ssh_Re   (ntides, eta_rho, xi_rho) float32 2kB ...
#     ssh_Im   (ntides, eta_rho, xi_rho) float32 2kB ...
#     pot_Re   (ntides, eta_rho, xi_rho) float32 2kB ...
#     pot_Im   (ntides, eta_rho, xi_rho) float32 2kB ...
#     u_Re     (ntides, eta_rho, xi_u) float32 2kB ...
#     u_Im     (ntides, eta_rho, xi_u) float32 2kB ...
#     v_Re     (ntides, eta_v, xi_rho) float32 1kB ...
#     v_Im     (ntides, eta_v, xi_rho) float32 1kB ...
# Attributes:
#     title:                 ROMS tidal forcing created by ROMS-Tools
#     roms_tools_version:    4.0.0a1
#     source:                TPXO
#     model_reference_date:  2000-01-01 00:00:00
# ----------------------------------------------------------------------------------------------------
# forcing.river
# <xarray.Dataset> Size: 140kB
# Dimensions:           (river_time: 12, nriver: 41, ntracers: 34, eta_rho: 4,
#                        xi_rho: 8)
# Coordinates:
#     month             (river_time) int32 48B ...
#     river_name        (nriver) object 328B ...
#   * nriver            (nriver) int32 164B 1 2 3 4 5 6 7 ... 35 36 37 38 39 40 41
#     abs_time          (river_time) datetime64[ns] 96B ...
#   * river_time        (river_time) float64 96B 15.0 45.0 74.0 ... 319.0 349.0
#     tracer_name       (ntracers) object 272B ...
#     tracer_unit       (ntracers) object 272B ...
#     tracer_long_name  (ntracers) object 272B ...
# Dimensions without coordinates: ntracers, eta_rho, xi_rho
# Data variables:
#     river_volume      (river_time, nriver) float64 4kB ...
#     river_tracer      (river_time, ntracers, nriver) float64 134kB ...
#     river_index       (eta_rho, xi_rho) float32 128B ...
#     river_fraction    (eta_rho, xi_rho) float32 128B ...
# Attributes:
#     climatology:  True
# ----------------------------------------------------------------------------------------------------
# cdr_forcing
# <xarray.Dataset> Size: 1kB
# Dimensions:           (time: 2, ncdr: 1, ntracers: 34)
# Coordinates:
#   * time              (time) datetime64[ns] 16B 2012-01-01 2012-01-02
#     release_name      (ncdr) object 8B ...
#     tracer_name       (ntracers) object 272B ...
#     tracer_unit       (ntracers) object 272B ...
#     tracer_long_name  (ntracers) object 272B ...
# Dimensions without coordinates: ncdr, ntracers
# Data variables:
#     cdr_time          (time) float64 16B ...
#     cdr_lon           (ncdr) float64 8B ...
#     cdr_lat           (ncdr) float64 8B ...
#     cdr_dep           (ncdr) float64 8B ...
#     cdr_hsc           (ncdr) float64 8B ...
#     cdr_vsc           (ncdr) float64 8B ...
#     cdr_trcflx        (time, ntracers, ncdr) float64 544B ...

# %% [markdown]
# ## Configure Build
#
# Generate the compile-time (`cppdefs.opt`) and run-time (`namelist.nml`) configuration files. This prepares the BUILD stage.

# %%
# configure and build the model
ocn.configure_build(compile_time_settings={}, run_time_settings={})
# Out:
# /Users/eilerman/git/C-Star/cstar/orchestration/models.py:194: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `ROMSCompositeCodeRepository` - serialized value may not be as expected [field_name='code', input_value={'roms': {'documentation'...h': '', 'filter': None}}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `Dataset` - serialized value may not be as expected [field_name='initial_conditions', input_value={'documentation': '', 'lo... 'partitioned': False}]}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `Dataset` - serialized value may not be as expected [field_name='grid', input_value={'documentation': '', 'lo... 'partitioned': False}]}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `ForcingConfiguration` - serialized value may not be as expected [field_name='forcing', input_value={'boundary': {'documentat...]}, 'corrections': None}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `PartitioningParameterSet` - serialized value may not be as expected [field_name='partitioning', input_value={'documentation': '', 'lo...s_x': 1, 'n_procs_y': 1}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `Dataset` - serialized value may not be as expected [field_name='cdr_forcing', input_value={'documentation': '', 'lo... 'partitioned': False}]}, input_type=dict])
#   data = handler(self)

# %% [markdown]
# ## Run C-Star

# %%
ocn.prep_cstar_environment(
   account_key = None,  # None gets from machine config or override here
   queue_name = None,  # None gets from machine config or override here
   walltime = "00:10:00",
   clobber = True,  # recommend True, but it will clear previous results from this run 
   n_procs_available = 0,  # 0 is auto-detect, change if on a login or shared node to not overuse resources
)

# %%
# Run C-Star via CLI
# This is recommended in order to get people used to using the CLI for these operations

import os
os.environ["THIS_BP_PATH"] = str(ocn.path_blueprint(stage="build"))

# !echo $THIS_BP_PATH
# !cstar blueprint run $THIS_BP_PATH
# Out:
# /Users/eilerman/cstar-forge-data/catalog/blueprints/MacOS/cson_roms-marbl_v0.1_test-tiny_1procs/B_cson_roms-marbl_v0.1_test-tiny_1procs_build.yml
# 2026-06-15 14:29:29,603 [INFO] - simulation.py:1258 - 🛠️ Configuring ROMSSimulation
# 2026-06-15 14:29:29,603 [INFO] - simulation.py:1261 - 🔧 Setting up ROMSExternalCodeBase...
# 2026-06-15 14:29:39,432 [INFO] - simulation.py:1261 - 🔧 Setting up MARBLExternalCodeBase...
# 2026-06-15 14:29:55,282 [INFO] - simulation.py:1275 - 📦 Fetching compile-time code...
# 2026-06-15 14:29:55,283 [INFO] - simulation.py:1280 - 📦 Fetching runtime code...
# 2026-06-15 14:29:55,284 [INFO] - simulation.py:1285 - 📦 Fetching input datasets...
# 2026-06-15 14:30:09,260 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_grid.nc into (1,1)
# 2026-06-15 14:30:14,711 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_initial_conditions.nc into (1,1)
# 2026-06-15 14:30:14,739 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_tidal.nc into (1,1)
# 2026-06-15 14:30:14,747 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_river.nc into (1,1)
# 2026-06-15 14:30:14,756 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-physics_201112.nc into (1,1)
# 2026-06-15 14:30:14,766 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-physics_201201.nc into (1,1)
# 2026-06-15 14:30:14,777 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-bgc_clim.nc into (1,1)
# 2026-06-15 14:30:14,815 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-physics_201112.nc into (1,1)
# 2026-06-15 14:30:14,824 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-physics_201201.nc into (1,1)
# 2026-06-15 14:30:14,832 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc_clim.nc into (1,1)
# 2026-06-15 14:30:14,839 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc-co2_2011.nc into (1,1)
# 2026-06-15 14:30:14,843 [INFO] - input_dataset.py:279 - Partitioning /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc-co2_2012.nc into (1,1)
# 2026-06-15 14:30:14,852 [INFO] - simulation.py:1641 - Running mpirun -n 1 ./roms cstar_generated_roms.nml
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  grid file: /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_grid.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  initial condition :: rec =  1  file = '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_initial_conditions.0.nc'
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  forcing data file(s): /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_tidal.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_river.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-physics_201112.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-physics_201201.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc_clim.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc-co2_2011.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_surface-bgc-co2_2012.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-physics_201112.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-physics_201201.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -                        /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_boundary-bgc_clim.0.nc
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  MARBL config file               /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -      gamma2 = 1.000E+00  slipperiness parameter: free-slip = +1, or no-slip = -1.
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -        rdrg = 0.000E+00  linear bottom drag coefficient [m/s]
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -       rdrg2 = 1.000E-03  quadratic bottom drag coefficient, nondim
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -         Zob = 1.000E-02  bottom roughness height [m]
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -     Akv_bak = 0.000E+00  additional vertical viscosity [m^2/s]
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(1) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #1
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(2) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #2
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(3) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #3
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(4) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #4
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(5) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #5
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(6) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #6
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(7) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #7
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(8) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #8
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(9) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #9
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #10
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #11
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #12
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #13
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #14
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #15
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #16
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #17
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #18
# 2026-06-15 14:30:15,278 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #19
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #20
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #21
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #22
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #23
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #24
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #25
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #26
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #27
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #28
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #29
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #30
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #31
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #32
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #33
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Akt_bak(*) = 0.000E+00  additional vertical mixing [m^2/s] for tracer #34
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -       visc2 = 0.000E+00  horizontal Laplacian kinematic viscosity [m^2/s]
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -      ntimes =        12   total number of 3D timesteps
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -          dt =  7200.0000  time step [sec] for 3D equations
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -     ndtfast =        60   mode-splitting ratio
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -       ninfo =         1   number of steps between runtime diagnostics
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -       ubind = 1.000E-01  open boundary binding velcity [m/s]
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -    v_sponge =      0.00  maximum viscosity in sponge layer [m^2/s]
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -     theta_s = 5.0000000  vertical S-coordinate surface
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -     theta_b = 2.0000000  and bottom stretching parameters
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -          hc = 250.00000  critical depth [m]
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - No SLURM or PBS job ID found.
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Activated CPP configuration switches:
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Git hash:
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  neighbors att not found/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_grid.0.nc
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -  Mode splitting: ndtfast = 60    nfast =  82        p,q,r =  2.0  4.0   0.2500
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: abio_dic_on = .false.
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: base_bio_on = .true.
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: ciso_on = .false.
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: PFT_defaults = "CESM2"
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_cnt = 3
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: max_grazer_prey_cnt = 3
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: zooplankton_cnt = 1
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,279 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: ladjust_bury_coeff = .false.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lcheck_forcing = .false.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lcompute_nhx_surface_emis = .true.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lecovars_full_depth_tavg = .false.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lflux_gas_co2 = .true.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lflux_gas_o2 = .true.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lo2_consumption_scalef = .false.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lp_remin_scalef = .false.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lsource_sink = .true.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: lvariable_PtoC = .true.
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: init_bury_coeff_opt = "settings_file"
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: Jint_Ctot_thres_molpm2pyr = 1e-09
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: QCaCO3_max = 0.4
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: auto_mort2_exp = 1.75
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: bftt_dz_sum_thres = 1e-14
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: bury_coeff_rmean_timescale_years = 10.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: caco3_bury_thres_depth =   3.0000000000000000e+05
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: caco3_bury_thres_omega_calc = 1.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: caco3_bury_thres_opt = "omega_calc"
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: f_graze_CaCO3_remin = 0.33
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: gQ_Fe_kFe_thres = 10.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: gQ_Si_kSi_thres = 5.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: gQsi_0 = 0.137
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: gQsi_max = 0.685
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: gQsi_min = 0.0457
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: o2_sf_o2_range_hi = 45.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: o2_sf_o2_range_lo = 5.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: o2_sf_val_lo_o2 = 3.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_CaCO3_gamma = 0.1
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_Fe_bioavail = 1.0
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_Fe_desorption_rate0 =   9.9999999999999995e-07
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_Lig_degrade_rate0 = 9.4e-05
# 2026-06-15 14:30:15,280 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_SiO2_gamma = 0.1
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_f_prod_sp_CaCO3 = 0.07
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_hPOC_CaCO3_ratio = 0.05
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_hPOC_SiO2_ratio = 0.05
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_hPOC_dust_ratio = 0.05
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_labile_ratio = 0.94
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_o2_min = 5.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_o2_min_delta = 5.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_sed_denitrif_coeff = 1.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: particulate_flux_ref_depth = 10000.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: zoo_mort2_exp = 1.5
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: POM_bury_frac_max = 0.8
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: PON_bury_coeff = 0.5
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: bSi_bury_frac_max = 1.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_init_POC_bury_coeff = 1.1
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_init_POP_bury_coeff = 1.1
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_init_bSi_bury_coeff = 1.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_CaCO3_diss =   5.0000000000000000e+04
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_POC_diss =   1.0000000000000000e+04
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_SiO2_diss =   6.5000000000000000e+04
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_kappa_nitrif_per_day = 0.06
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_nitrif_par_lim = 1.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_FeLig_scavenge_rate0 = 1.3
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_Fe_scavenge_rate0 = 24.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_Lig_scavenge_rate0 = 0.015
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_vals(1) = 1.0
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_vals(2) = 3.2
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_vals(3) = 4.8
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_vals(4) = 5.3
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_z(1) =   1.0000000000000000e+04
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_z(2) =   2.5000000000000000e+04
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_z(3) =   5.0000000000000000e+04
# 2026-06-15 14:30:15,281 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: parm_scalelen_z(4) =   1.0000000000000000e+05
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in:
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%Ea = 0.32
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%Nfixer = .false.
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%PCref_per_day = 5.0
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%Qp_fixed =   8.5470085470085479e-03
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%agg_rate_max = 0.5
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%agg_rate_min = 0.01
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%alphaPI_per_day = 0.39
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%exp_calcifier = .false.
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%gQfe_0 =   3.4999999999999997e-05
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%gQfe_min = 2.7e-06
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%imp_calcifier = .true.
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%is_carbon_limited = .false.
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%kCO2 = 0.0
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%kDOP = 0.3
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%kFe = 3e-05
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%kNH4 = 0.01
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%kNO3 = 0.25
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%kPO4 = 0.01
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%kSiO3 = 0.0
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%lname = "Small Phyto"
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%loss_poc = 0.0
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%loss_thres = 0.01
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%loss_thres2 = 0.0
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%mort2_per_day = 0.01
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%mort_per_day = 0.1
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%silicifier = .false.
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%sname = "sp"
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%temp_func_form_opt = "q_10"
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%temp_thres = -10.0
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(1)%thetaN_max = 2.5
# 2026-06-15 14:30:15,282 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%Ea = 0.32
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%Nfixer = .false.
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%PCref_per_day = 5.0
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%Qp_fixed =   8.5470085470085479e-03
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%agg_rate_max = 0.5
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%agg_rate_min = 0.02
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%alphaPI_per_day = 0.39
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%exp_calcifier = .false.
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%gQfe_0 =   3.4999999999999997e-05
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%gQfe_min = 2.7e-06
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%imp_calcifier = .false.
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%is_carbon_limited = .false.
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%kCO2 = 0.0
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%kDOP = 0.5
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%kFe = 5.5e-05
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%kNH4 = 0.05
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%kNO3 = 0.5
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%kPO4 = 0.05
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%kSiO3 = 0.7
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%lname = "Diatom"
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%loss_poc = 0.0
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%loss_thres = 0.02
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%loss_thres2 = 0.0
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%mort2_per_day = 0.01
# 2026-06-15 14:30:15,283 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%mort_per_day = 0.1
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%silicifier = .true.
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%sname = "diat"
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%temp_func_form_opt = "q_10"
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%temp_thres = -10.0
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(2)%thetaN_max = 4.0
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%Ea = 0.32
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%Nfixer = .true.
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%PCref_per_day = 2.5
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%Qp_fixed =   2.7350427350427355e-03
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%agg_rate_max = 0.5
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%agg_rate_min = 0.01
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%alphaPI_per_day = 0.39
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%exp_calcifier = .false.
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%gQfe_0 =   6.9999999999999994e-05
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%gQfe_min = 5.4e-06
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%imp_calcifier = .false.
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%is_carbon_limited = .false.
# 2026-06-15 14:30:15,284 [INFO] - handler.py:195 - /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/runtime_code/marbl_in: autotroph_settings(3)%kCO2 = 0.0
# ...
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -       2  -3.3333E-01  -5.3739079E-02    -5.3739079E+18  -4.8384052E+01   2.6869539E+18   5.3739079E+18
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -       1  -6.6667E-01  -3.4645913E-01    -3.4645913E+19  -1.2664072E+02   1.7322956E+19   3.4645913E+19
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -       0  -1.0000E+00  -1.0000000E+00    -1.0000000E+20  -2.5000000E+02   5.0000000E+19   1.0000000E+20
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  Spherical grid detected.
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  init buffers
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -       get_grid :: read grid data from file '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_grid.0.nc'.
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  allocating pflux vars
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  hmin =   44.256673   grdmin = 2.0396467E+05     area = 2.4988053338396704E+11
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  hmax =  109.251397   grdmax = 2.0412195E+05   volume = 1.9014824472964953E+13
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -                                            open_cross = 1.8478316393560106E+08
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  Cg_max = 0.0477926   Cg_min = 0.0304340   Cu_Cor = 0.9276880
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  Maximum grid stiffness ratios:   rx0 = 0.189154150  rx1 =   0.753740506
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  WARNING: Exact restart is requested, but is not possible: initial
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -           file '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_initial_conditions.0.nc' does not contain sufficient records.
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  riv_umask not found in initial file. Initializing to zero.
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  riv_vmask not found in initial file. Initializing to zero.
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  WARNING: netCDF variable 'hbls' not found in '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_initial_conditions.0.nc' ==> initialized to zero state.
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  WARNING: netCDF variable 'hbbl' not found in '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0_1_test-tiny_1procs_initial_conditions.0.nc' ==> initialized to zero state.
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: MARBL_PH_SURF not in initial file.  Initialized to 0.0
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: MARBL_ABIO_PH_SURF not in initial file.  Initialized to 0.0
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: MARBL_PH_SURF_ALT_CO2 not in initial file.  Initialized to 0.0
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: MARBL_PH_3D not in initial file.  Initialized to 0.0
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: MARBL_PH_3D_ALT_CO2 not in initial file.  Initialized to 0.0
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  getting u,v,p slow
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: u_slow not in initial file.  Initialized to u
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: v_slow not in initial file.  Initialized to v
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -   --- WARNING: p_slow not in initial file.  Initialized to 0.0
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -       get_init :: Read initial conditions for day =   4383.0000 record =   1
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -       get_init :: set closed west  boundary row to zero (u/ub/v/vb)
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -       get_init :: set closed south boundary row to zero (u/ub/v/vb)
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -  Finished inits
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -          set_frc :: swrad            input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -          set_frc :: swrad            input time (days) =   4383.04     rec =   2
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -          set_frc :: lwrad            input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -          set_frc :: lwrad            input time (days) =   4383.04     rec =   2
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -          set_frc :: uwnd             input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -          set_frc :: uwnd             input time (days) =   4383.04     rec =   2
# 2026-06-15 14:30:15,310 [INFO] - handler.py:195 -          set_frc :: vwnd             input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: vwnd             input time (days) =   4383.04     rec =   2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: Tair             input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: Tair             input time (days) =   4383.04     rec =   2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: qair             input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: qair             input time (days) =   4383.04     rec =   2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: rain             input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: rain             input time (days) =   4383.04     rec =   2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: dust             input time (days) =   4367.25     rec =  12
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: dust             input time (days) =   4398.50     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: iron             input time (days) =   4367.25     rec =  12
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: iron             input time (days) =   4398.50     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: xco2_air         input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: xco2_air         input time (days) =   4390.62     rec =   2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: xco2_air_alt     input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: xco2_air_alt     input time (days) =   4390.62     rec =   2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: nox              input time (days) =   4367.25     rec =  12
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: nox              input time (days) =   4398.50     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: nhy              input time (days) =   4367.25     rec =  12
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: nhy              input time (days) =   4398.50     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: river_volume     input time (days) =   4366.75     rec =  12
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: river_volume     input time (days) =   4398.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: river_tracer     input time (days) =   4366.75     rec =  12
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: river_tracer     input time (days) =   4398.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -        river_frc: init river locations
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -  The minimum distance to Release           1 is   178728.37493265705
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -  This is on rank:           0
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -  at point           5           2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -  The intended release location was Lon:   1.0000000000000000      Lat:   59.000000000000000
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -  The release will take place at Lon:   1.3304702708226628      Lat:   57.402112495197201
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -        cdr_frc: init cdr locations
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: cdr_trcflx       input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          set_frc :: cdr_trcflx       input time (days) =   4384.00     rec =   2
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -  Sponge layer =  15 interior grid points.
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -  init cdr output
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -               cdr_output :: average file  recs/file =     24  output_period =  3600.0
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -        avg fields to be saved: (T/F)
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          --------------------------------------------------------------
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            Name    Write (T/F)     Long name
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -          --------------------------------------------------------------
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            avg_begin_time    T     Time at beginning of averaging period
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            avg_end_time      T     Time at end of averaging period
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            zeta              T     free-surface elevation
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            temp              T     potential temperature
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            salt              T     salinity
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            ALK               T     Alkalinity
# 2026-06-15 14:30:15,311 [INFO] - handler.py:195 -            DIC               T     Dissolved Inorganic Carbon
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            ALK_ALT_CO2       T     Alkalinity, Alternative CO2
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            DIC_ALT_CO2       T     Dissolved Inorganic Carbon, Alternative CO2
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            hALK              T     thickness-weighted Alkalinity
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            hDIC              T     instantaneous thickness-weighted Dissolved Inorganic Carbon
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            hALK_ALT_CO2      T     thickness-weighted Alkalinity, Alternative CO2
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            hDIC_ALT_CO2      T     instantaneous thickness-weighted Dissolved Inorganic Carbon, Alternative CO2
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            pH                T     3D pH
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            pH_ALT_CO2        T     3D pH (alternate CO2)
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            FG_CO2            T     DIC Surface Gas Flux
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            FG_ALT_CO2        T     DIC Surface Gas Flux, Alternative CO2
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            ALK_source        T     ALK source from CDR module
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            ALK_ALT_source    T     alt ALK source from CDR module
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            DIC_source        T     DIC source from CDR module
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            DIC_ALT_source    T     alt DIC source from CDR module
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            hDIC_avg          T     time-averaged thickness-weighted Dissolved Inorganic Carbon
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -            hDIC_ALT_CO2_avg  T     time-averaged thickness-weighted Dissolved Inorganic Carbon
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -          --------------------------------------------------------------
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -  main :: initialization complete, started time-stepping.
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -  STEP  time[DAYS] KINETIC_ENRG     BAROTR_KE        MAX_ADV_CFL     MAX_VERT_CFL     i_cx   j_cx  k_c  WALLTIME0
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -       0 4383.0000 1.86852086479-03 1.7398812422-03  0.007955654394  0.000000000000      3      2    1       0.116
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -          set_frc :: zeta_east        input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,312 [INFO] - handler.py:195 -          set_frc :: zeta_east        input time (days) =   4384.00     rec =   2
# 2026-06-15 14:30:15,816 [INFO] - handler.py:195 -          set_frc :: zeta_north       input time (days) =   4383.00     rec =   1
# 2026-06-15 14:30:15,816 [INFO] - handler.py:195 -          set_frc :: zeta_north       input time (days) =   4384.00     rec =   2
# 2026-06-15 14:30:20,918 [WARNING] - handler.py:152 - This job is currently not running (completed). Live updates cannot be provided. See /Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/logs/cstar_worker_20260615_202926.out for job output
# 2026-06-15 14:30:20,920 [INFO] - simulation.py:91 - Spatial join of netCDF files 'output_cdr.20120101020000.*.nc' starting
# 2026-06-15 14:30:20,920 [INFO] - simulation.py:91 - Spatial join of netCDF files 'output_rst.20120102000000.*.nc' starting
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# 2026-06-15 14:30:21,232 [INFO] - simulation.py:100 - Spatial join of '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/joined_output/output_cdr.20120101020000.nc' is complete
# 2026-06-15 14:30:21,236 [INFO] - simulation.py:100 - Spatial join of '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/joined_output/output_rst.20120102000000.nc' is complete
# 2026-06-15 14:30:21,237 [INFO] - runner.py:117 - BlueprintRunner reached a terminal state 'completed'
# 2026-06-15 14:30:21,237 [INFO] - service.py:322 - Shutting down service.
# 2026-06-15 14:30:21,237 [INFO] - runner.py:94 - Simulation completed successfully.
# Blueprint execution completed

# %%
# Or use the wrapper function on the SpecBuilder
# This might be needed if the environment on an HPC doesn't handle the !bash commands correctly

# await ocn.run()

# Note: if you want to call this run method from a non-notebook script, you need to do the following:
# import asyncio
# asyncio.run(ocn.run())

# %% [markdown]
# ## Visualize Model Output
#
# After the model run completes, you can load and visualize the output data. The code below:
#
# 1. **Finds output files**: Uses `glob` to locate all BGC (biogeochemical) output files in the `JOINED_OUTPUT` directory
# 2. **Opens the dataset**: Uses `xarray.open_mfdataset()` to open multiple NetCDF files as a single dataset
# 3. **Applies land mask**: Masks out land points using the grid's `mask_rho` variable
# 4. **Plots a variable**: Creates a plot of dissolved inorganic carbon (DIC) at the first time step and bottom vertical level (`s_rho=-1`)
#
# The `JOINED_OUTPUT` directory contains the spatially-joined output files created by `post_run()`, which combine partitioned output files from parallel runs into single files.

# %%
str(ocn.run_output_dir / "joined_output" / (ocn.casename + "_bgc.*"))
# Out:
# '/Users/eilerman/cstar-forge-data/cstar-forge-run/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102/joined_output/cson_roms-marbl_v0.1_test-tiny_1procs_20120101-20120102_bgc.*'

# %%
# import xarray as xr
# from glob import glob

# files = glob(str(ocn.run_output_dir / "output" / ("output_bgc.*")))
# ds = xr.open_mfdataset(files)
# ds = ds.where(ocn.grid.ds.mask_rho)
# ds.DIC.isel(eta_rho=2, xi_rho=6, s_rho=-1).plot(marker="o", color="red")

# %% [markdown]
# ### CDR Plots

# %%
from roms_tools import ROMSOutput

roms_out = ROMSOutput(grid=ocn.grid, path=ocn.run_output_dir / "joined_output" / "output_cdr.*.nc", use_dask=True)
roms_out.cdr_metrics()

# %% [markdown]
# ## Set Blueprint State
#
# The `set_blueprint_state()` method updates the state of the blueprint, which tracks the workflow stage of the simulation specification. Blueprint states indicate the current stage of the workflow (e.g., "draft", "configured", "ready") and are used by the C-Star orchestration system to manage the simulation lifecycle.
#
# Common blueprint states include:
# - `"draft"`: The blueprint is in development and not yet finalized
# - `"validated"`: The blueprint has been validated
#
# Setting the state to `"draft"` is useful when you want to mark the blueprint as a work-in-progress that may need further modifications before execution.

# %%
ocn.set_blueprint_state(state="draft")

# %% [markdown]
# ## Save Executed Notebook
#
# Save a timestamped copy of this notebook to `executed/forge/{os}/` for reproducibility and record-keeping. The copy is organized by operating system (macOS or Ubuntu/Linux) to track execution history across different platforms.
#
# The saved notebook includes all executed cells and outputs, providing a complete record of the simulation workflow for future reference.

# %%
# Save the notebook copy
cstar_forge.save_notebook_copy(notebook_name="CStarSpecBuilder-demo.ipynb")
# Out:
# Notebook copy saved to: executed/forge/MacOS/CStarSpecBuilder-demo_MacOS.ipynb
# PosixPath('executed/forge/MacOS/CStarSpecBuilder-demo_MacOS.ipynb')
